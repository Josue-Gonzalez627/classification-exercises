# %% [markdown]
# # Exercises (Data Acquisition)

# %% [markdown]
# The end product of these exercises is a jupyter notebook, acquire.ipynb, and an acquire.py file. The notebook will contain all your work as you move through the exercises. The acquire.py file should contain the final functions that acquire the data into a pandas dataframe.
#
# Make a new repo called classification-exercises on both GitHub and within your codeup-data-science directory. This will be where you do your work for this module.
#
# Inside of your local classification-exercises repo, create a file named .gitignore with the following contents:
#
#
# env.py
# .DS_Store
# .ipynb_checkpoints/
# __pycache__
# *.csv
# Add and commit your .gitignore file before moving forward.
#
# Create or copy your env.py file inside of classification-exercises
#
# Run git status
#
# The env.py file should not be tracked by git
#
# Do the following exercises in a jupyter notebook titled acquire.ipynb.

# %%
import pandas as pd
import numpy as np

from pydataset import data

import os
import env

# %% [markdown]
# ### 5. Use pydata to import the iris data. Create a pandas dataframe, df_iris, from this data.

# %%
df_iris = data('iris')

# %% [markdown]
# #### print the first 3 rows

# %%
df_iris.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# #### print the number of rows and columns (shape)

# %%
df_iris.shape #row, columns
# Out:
# (150, 5)

# %% [markdown]
# #### print the column names

# %%
df_iris.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %% [markdown]
# #### print the data type of each column

# %%
df_iris.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
df_iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# #### print the summary statistics for each of the numeric variables

# %%
df_iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### 6. Read the data from this google sheet into a dataframe, df_google.

# %%
url = 'https://docs.google.com/spreadsheets/d/\
1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'

# %%
new_url = url.replace('/edit#gid=', '/export?format=csv&gid=')

# %%
df_google = pd.read_csv(new_url)

# %% [markdown]
# #### print the first 3 rows

# %%
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# #### print the number of rows and columns

# %%
df_google.shape
# Out:
# (891, 12)

# %% [markdown]
# #### print the column names

# %%
df_google.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #### print the data type of each column

# %%
df_google.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### print the summary statistics for each of the numeric variables

# %%
df_google.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #### print the unique values for each of your categorical variables

# %%
df_google.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df_google.Name.value_counts() 
### wouldn't use as a categorical because it has many unique values
### but technically is one
    ### we'd have to pull something out of it (group something)
# Out:
# Name
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: count, Length: 891, dtype: int64

# %%
df_google.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
cat_col = df_google.columns [df_google.nunique() < 10]
cat_col
### used to find the columns with less than 10 unique values
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked'], dtype='object')

# %%
for col in cat_col:
    print(df_google[col].value_counts())
    print()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64
#
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
#
# Sex
# male      577
# female    314
# Name: count, dtype: int64
#
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64
#
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64
#
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df_google.Cabin.value_counts()
# Out:
# Cabin
# B96 B98            4
# G6                 4
# C23 C25 C27        4
# C22 C26            3
# F33                3
# F2                 3
# E101               3
# D                  3
# C78                2
# C93                2
# E8                 2
# D36                2
# B77                2
# C123               2
# E121               2
# E44                2
# D35                2
# C125               2
# E67                2
# B35                2
# B18                2
# E24                2
# B49                2
# C65                2
# B20                2
# B5                 2
# B57 B59 B63 B66    2
# C126               2
# B51 B53 B55        2
# F4                 2
# C124               2
# F G73              2
# B58 B60            2
# C52                2
# D33                2
# C68                2
# D20                2
# D26                2
# B28                2
# C83                2
# E25                2
# D17                2
# B22                2
# ...

# %%
df_google.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df_google.Survived.astype(object)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: object

# %%
df_google.select_dtypes(include = 'object')
### gets only categorical columns I believe... That's why I changed the survived
### column to an object since it was an INT before.

    ### but isn't pclass also categorical??? idk (1st, 2nd, or 3rd class)
# Out:
#                                                     Name     Sex  \
# 0                                Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female
# 2                                 Heikkinen, Miss. Laina  female
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                               Allen, Mr. William Henry    male
# ..                                                   ...     ...
# 886                                Montvila, Rev. Juozas    male
# 887                         Graham, Miss. Margaret Edith  female
# 888             Johnston, Miss. Catherine Helen "Carrie"  female
# 889                                Behr, Mr. Karl Howell    male
# 890                                  Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# ...

# %%
df_google
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ### 7. Download the google sheet from Exercise 6 into an .xlsx (File → Download → Microsoft Excel). Read the downloaded file into a dataframe named df_excel.

# %% [markdown]
# #### assign the first 100 rows to a new dataframe, df_excel_sample

# %%
df_excel = pd.read_excel('~/Downloads/train.xlsx') ### could put the absolute path

# %%
df_excel_sample = df_excel.head(100).copy() 

#this makes an actual copy compared to ONLY assigning a variable to it
    ### df_excel_sample = df_excel.head(100) ### don't only do this, add .copy()

# %% [markdown]
# #### print the number of rows of your original dataframe

# %%
df_excel.shape
# Out:
# (891, 12)

# %%
df_excel_sample.shape ### here we have the desired copy with only 100 rows
# Out:
# (100, 12)

# %% [markdown]
# #### print the first 5 column names

# %%
df_excel_sample.columns[:5]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex'], dtype='object')

# %% [markdown]
# #### print the column names that have a data type of object

# %%
df_excel_sample.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df_excel_sample.select_dtypes(include = 'object').columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### compute the range for each of the numeric variables.

# %%
num_col = df_excel_sample.select_dtypes(include ='number').columns
num_col
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
for col in num_col:
#     print(col)
#     print(df_excel_sample[col])
    print(f'The range of {col} is {(df_excel_sample[col]).max() - df_excel_sample[col].min()}')
    print()
# Out:
# The range of PassengerId is 99
#
# The range of Survived is 1
#
# The range of Pclass is 2
#
# The range of Age is 70.17
#
# The range of SibSp is 5
#
# The range of Parch is 5
#
# The range of Fare is 255.775

# %% [markdown]
# ## Make a new python module, acquire.py to hold the following data acquisition functions:

# %%
import pandas as pd
import numpy as np

from pydataset import data

from scipy import stats
import env

# %% [markdown]
# ### 1. Make a function named get_titanic_data that returns the Titanic data from the codeup data science database as a pandas data frame. Obtain your data from the Codeup Data Science Database.

# %%
def get_titanic_data():
    url = env.get_db_url('titanic_db')
    query = 'select * from passengers'
    
    df = pd.read_sql(query, url)
    return df

# %%
get_titanic_data().head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0
# 2        S  Third  None  Southampton      1
# 3        S  First     C  Southampton      0
# 4        S  Third  None  Southampton      1

# %% [markdown]
# ### 2. Make a function named get_iris_data that returns the data from the iris_db on the codeup data science database as a pandas data frame. The returned data frame should include the actual name of the species in addition to the species_ids. Obtain your data from the Codeup Data Science Database.

# %%
def get_iris_data():
    url = env.get_db_url('iris_db')
    query = '''
    select *
    from measurements
        join species
            using (species_id)
    '''
    
    df = pd.read_sql(query, url)
    return df

# %%
get_iris_data().head()
# Out:
#    species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0           1               1           5.1          3.5           1.4
# 1           1               2           4.9          3.0           1.4
# 2           1               3           4.7          3.2           1.3
# 3           1               4           4.6          3.1           1.5
# 4           1               5           5.0          3.6           1.4
#
#    petal_width species_name
# 0          0.2       setosa
# 1          0.2       setosa
# 2          0.2       setosa
# 3          0.2       setosa
# 4          0.2       setosa

# %% [markdown]
# ### 3. Make a function named get_telco_data that returns the data from the telco_churn database in SQL. In your SQL, be sure to join contract_types, internet_service_types, payment_types tables with the customers table, so that the resulting dataframe contains all the contract, payment, and internet service options. Obtain your data from the Codeup Data Science Database.

# %%
def get_telco_data():
    url = env.get_db_url('telco_churn')
    query = '''
    select *
    from customers
        left join contract_types
            using (contract_type_id) 
        left join internet_service_types
            using (internet_service_type_id)
        left join payment_types
            using (payment_type_id)
    '''
    df = pd.read_sql(query, url)
    return df

# %%
get_telco_data().head()
# Out:
#    payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                2                         1                 2  0002-ORFBO
# 1                2                         1                 1  0003-MKNFE
# 2                1                         2                 1  0004-TLHLJ
# 3                1                         2                 1  0011-IGKFF
# 4                2                         2                 1  0013-EXCHZ
#
#    gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 0  Female               0     Yes        Yes       9           Yes  ...
# 1    Male               0      No         No       9           Yes  ...
# 2    Male               0      No         No       4           Yes  ...
# 3    Male               1     Yes         No      13           Yes  ...
# 4  Female               1     Yes         No       3           Yes  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %%
import acquire

# %%
acquire.get_telco_data().head() ###not sure what this part is/was
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 acquire.get_telco_data().head()
#
# AttributeError: module 'acquire' has no attribute 'get_telco_data'

# %% [markdown]
# ## 4. Once you've got your get_titanic_data, get_iris_data, and get_telco_data functions written, now it's time to add caching to them. To do this, edit the beginning of the function to check for the local filename of telco.csv, titanic.csv, or iris.csv. If they exist, use the .csv file. If the file doesn't exist, then produce the SQL and pandas necessary to create a dataframe, then write the dataframe to a .csv file with the appropriate name.

# %%
def check_file_exists(filename, query, url):
    if os.path.exists(filename):
        print('this file exists, reading csv')
        df = pd.read_csv(filename, index_col=0)
            ### index_col=0 is to create the index I beleive, because without it,
            ### it made an "unnamed column"
    else:
        print('this file doesn\'t exist, read from sql, and export to csv')
        df = pd.read_sql(query, url)
        df.to_csv(filename)
        
    return df

# %%
def get_titanic_data():
    url = env.get_db_url('titanic_db')
    query = 'select * from passengers'
    
    filename = 'titanic.csv'
    
    #call the check_file_exists function
    df = check_file_exists(filename, query, url)
    return df

# %%
get_titanic_data() ### If ran twice, will NOW exist, doesn't the 1st time 
    ### (creates it and I'll see it in my files)
# Out:
# this file exists, reading csv
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class deck  embark_town  alone
# ...

# %%
def get_iris_data():
    url = env.get_db_url('iris_db')
    query = '''
    select *
    from measurements
        join species
            using (species_id)
    ''' 
    
    filename = 'iris.csv'
    
     #call the check_file_exists function
    df = check_file_exists(filename, query, url)
    return df

# %%
get_iris_data()
# Out:
# this file exists, reading csv
#      species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0             1               1           5.1          3.5           1.4
# 1             1               2           4.9          3.0           1.4
# 2             1               3           4.7          3.2           1.3
# 3             1               4           4.6          3.1           1.5
# 4             1               5           5.0          3.6           1.4
# 5             1               6           5.4          3.9           1.7
# 6             1               7           4.6          3.4           1.4
# 7             1               8           5.0          3.4           1.5
# 8             1               9           4.4          2.9           1.4
# 9             1              10           4.9          3.1           1.5
# 10            1              11           5.4          3.7           1.5
# ...

# %%
def get_telco_data():
    url = env.get_db_url('telco_churn')
    query = '''
    select *
    from customers
        left join contract_types
            using (contract_type_id) 
        left join internet_service_types
            using (internet_service_type_id)
        left join payment_types
            using (payment_type_id)
    '''
    
    filename = 'telco_churn.csv'
    
    #call the check_file_exists function
    df = check_file_exists(filename, query, url)
    return df

# %%
get_telco_data()
# Out:
# this file exists, reading csv
#       payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                   2                         1                 2  0002-ORFBO
# 1                   2                         1                 1  0003-MKNFE
# 2                   1                         2                 1  0004-TLHLJ
# 3                   1                         2                 1  0011-IGKFF
# 4                   2                         2                 1  0013-EXCHZ
# ...               ...                       ...               ...         ...
# 7038                2                         1                 2  9987-LUTYD
# 7039                1                         2                 1  9992-RRAMN
# 7040                2                         1                 1  9992-UJOEL
# 7041                2                         1                 3  9993-LHIEB
# 7042                1                         1                 3  9995-HOTOH
#
# ...

# %% [markdown]
# # **Make sure your env.py and csv files are not being pushed to GitHub!**

# %% [markdown]
# ### Now I can import my functions to my brand new acquire.py file!
# ##### Put the check file, iris, titanic, and telco funtions.
